# %%
import pandas as pd
df = pd.read_csv("churn.csv")
df.head()
# Out:
#    CustomerID   Age  Gender  Tenure  Usage Frequency  Support Calls  \
# 0         2.0  30.0  Female    39.0             14.0            5.0
# 1         3.0  65.0  Female    49.0              1.0           10.0
# 2         4.0  55.0  Female    14.0              4.0            6.0
# 3         5.0  58.0    Male    38.0             21.0            7.0
# 4         6.0  23.0    Male    32.0             20.0            5.0
#
#    Payment Delay Subscription Type Contract Length  Total Spend  \
# 0           18.0          Standard          Annual        932.0
# 1            8.0             Basic         Monthly        557.0
# 2           18.0             Basic       Quarterly        185.0
# 3            7.0          Standard         Monthly        396.0
# 4            8.0             Basic         Monthly        617.0
#
#    Last Interaction  Churn
# 0              17.0    1.0
# 1               6.0    1.0
# 2               3.0    1.0
# 3              29.0    1.0
# 4              20.0    1.0

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 440833 entries, 0 to 440832
# Data columns (total 12 columns):
#  #   Column             Non-Null Count   Dtype
# ---  ------             --------------   -----
#  0   CustomerID         440832 non-null  float64
#  1   Age                440832 non-null  float64
#  2   Gender             440832 non-null  str
#  3   Tenure             440832 non-null  float64
#  4   Usage Frequency    440832 non-null  float64
#  5   Support Calls      440832 non-null  float64
#  6   Payment Delay      440832 non-null  float64
#  7   Subscription Type  440832 non-null  str
#  8   Contract Length    440832 non-null  str
#  9   Total Spend        440832 non-null  float64
#  10  Last Interaction   440832 non-null  float64
#  11  Churn              440832 non-null  float64
# dtypes: float64(9), str(3)
# memory usage: 48.5 MB

# %%
import pandas as pd
df = pd.read_csv("churn.csv")
df.head()
# Out:
#    CustomerID   Age  Gender  Tenure  Usage Frequency  Support Calls  \
# 0         2.0  30.0  Female    39.0             14.0            5.0
# 1         3.0  65.0  Female    49.0              1.0           10.0
# 2         4.0  55.0  Female    14.0              4.0            6.0
# 3         5.0  58.0    Male    38.0             21.0            7.0
# 4         6.0  23.0    Male    32.0             20.0            5.0
#
#    Payment Delay Subscription Type Contract Length  Total Spend  \
# 0           18.0          Standard          Annual        932.0
# 1            8.0             Basic         Monthly        557.0
# 2           18.0             Basic       Quarterly        185.0
# 3            7.0          Standard         Monthly        396.0
# 4            8.0             Basic         Monthly        617.0
#
#    Last Interaction  Churn
# 0              17.0    1.0
# 1               6.0    1.0
# 2               3.0    1.0
# 3              29.0    1.0
# 4              20.0    1.0

# %%
df.columns
# Out:
# Index(['CustomerID', 'Age', 'Gender', 'Tenure', 'Usage Frequency',
#        'Support Calls', 'Payment Delay', 'Subscription Type',
#        'Contract Length', 'Total Spend', 'Last Interaction', 'Churn'],
#       dtype='str')

# %%
df['Churn']. value_counts
# Out:
# <bound method IndexOpsMixin.value_counts of 0         1.0
# 1         1.0
# 2         1.0
# 3         1.0
# 4         1.0
#          ...
# 440828    0.0
# 440829    0.0
# 440830    0.0
# 440831    0.0
# 440832    0.0
# Name: Churn, Length: 440833, dtype: float64>

# %%
 import matplotlib.pyplot as plt
 df['Churn'].value_counts().plot(kind='bar')
 plt.title("Customer Churn Count")
 plt.show()

# %%
import pandas as pd
df = pd.read_csv("churn.csv")
df.head()
# Out:
#    CustomerID   Age  Gender  Tenure  Usage Frequency  Support Calls  \
# 0         2.0  30.0  Female    39.0             14.0            5.0
# 1         3.0  65.0  Female    49.0              1.0           10.0
# 2         4.0  55.0  Female    14.0              4.0            6.0
# 3         5.0  58.0    Male    38.0             21.0            7.0
# 4         6.0  23.0    Male    32.0             20.0            5.0
#
#    Payment Delay Subscription Type Contract Length  Total Spend  \
# 0           18.0          Standard          Annual        932.0
# 1            8.0             Basic         Monthly        557.0
# 2           18.0             Basic       Quarterly        185.0
# 3            7.0          Standard         Monthly        396.0
# 4            8.0             Basic         Monthly        617.0
#
#    Last Interaction  Churn
# 0              17.0    1.0
# 1               6.0    1.0
# 2               3.0    1.0
# 3              29.0    1.0
# 4              20.0    1.0

# %%
 df.groupby('Gender')['Churn'].mean()
# Out:
# Gender
# Female    0.666691
# Male      0.491269
# Name: Churn, dtype: float64

# %%
df.groupby('Subscription Type')['Churn'].mean()
# Out:
# Subscription Type
# Basic       0.581782
# Premium     0.559417
# Standard    0.560700
# Name: Churn, dtype: float64

# %%
df.groupby('Support Calls')['Churn'].mean().head()
# Out:
# Support Calls
# 0.0    0.302826
# 1.0    0.303630
# 2.0    0.315513
# 3.0    0.416431
# 4.0    0.584981
# Name: Churn, dtype: float64

# %%
df.groupby('Churn')['Total Spend'].mean()
# Out:
# Churn
# 0.0    749.953111
# 1.0    541.285528
# Name: Total Spend, dtype: float64

# %%
df.groupby('Gender')['Churn'].mean().plot(kind='bar')
plt.title("Gender vs Churn")
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[7], line 2
#       1 df.groupby('Gender')['Churn'].mean().plot(kind='bar')
# ----> 2 plt.title("Gender vs Churn")
#       3 plt.show()
#
# NameError: name 'plt' is not defined

# %%
df.groupby('Subscription Type')['Churn'].mean().plot(kind='bar')
plt.title("Subscription Type vs Churn")
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 df.groupby('Subscription Type')['Churn'].mean().plot(kind='bar')
#       2 plt.title("Subscription Type vs Churn")
#       3 plt.show()
#
# NameError: name 'df' is not defined

# %%
import pandas as pd
df = pd.read_csv("churn.csv")
df.head()
# Out:
#    CustomerID   Age  Gender  Tenure  Usage Frequency  Support Calls  \
# 0         2.0  30.0  Female    39.0             14.0            5.0
# 1         3.0  65.0  Female    49.0              1.0           10.0
# 2         4.0  55.0  Female    14.0              4.0            6.0
# 3         5.0  58.0    Male    38.0             21.0            7.0
# 4         6.0  23.0    Male    32.0             20.0            5.0
#
#    Payment Delay Subscription Type Contract Length  Total Spend  \
# 0           18.0          Standard          Annual        932.0
# 1            8.0             Basic         Monthly        557.0
# 2           18.0             Basic       Quarterly        185.0
# 3            7.0          Standard         Monthly        396.0
# 4            8.0             Basic         Monthly        617.0
#
#    Last Interaction  Churn
# 0              17.0    1.0
# 1               6.0    1.0
# 2               3.0    1.0
# 3              29.0    1.0
# 4              20.0    1.0

# %%
df.groupby('Subscription Type')['Churn'].mean().plot(kind='bar')
plt.title("Subscription Type vs Churn")
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[3], line 2
#       1 df.groupby('Subscription Type')['Churn'].mean().plot(kind='bar')
# ----> 2 plt.title("Subscription Type vs Churn")
#       3 plt.show()
#
# NameError: name 'plt' is not defined

# %%
df.groupby('Support Calls')['Churn'].mean().plot()
plt.title("Support Calls vs Churn")
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[5], line 2
#       1 df.groupby('Support Calls')['Churn'].mean().plot()
# ----> 2 plt.title("Support Calls vs Churn")
#       3 plt.show()
#
# NameError: name 'plt' is not defined

# %%
df.corr(numeric_only=True)
# Out:
#                   CustomerID       Age    Tenure  Usage Frequency  \
# CustomerID          1.000000 -0.181977  0.044129         0.038455
# Age                -0.181977  1.000000 -0.011630        -0.007190
# Tenure              0.044129 -0.011630  1.000000        -0.026800
# Usage Frequency     0.038455 -0.007190 -0.026800         1.000000
# Support Calls      -0.482894  0.158451 -0.027640        -0.022013
# Payment Delay      -0.262029  0.061738 -0.016588        -0.014470
# Total Spend         0.359289 -0.084684  0.019006         0.018631
# Last Interaction   -0.125356  0.028980 -0.006903        -0.004662
# Churn              -0.839365  0.218394 -0.051919        -0.046101
#
#                   Support Calls  Payment Delay  Total Spend  Last Interaction  \
# CustomerID            -0.482894      -0.262029     0.359289         -0.125356
# Age                    0.158451       0.061738    -0.084684          0.028980
# ...

# %%
print('''
Project Conclusion:
Customers with a higher number of support calls are more likely to churn
Basic subscription users show higher churn compared to premium users
Customer engagement plays an important role in retention
Spending patterns influence customer loyalty and churn behavior
Improving customer service can significantly reduce churn
Identifying high-risk customers can help in better retention strategies
''')
# Out:
# Project Conclusion:
# Customers with a higher number of support calls are more likely to churn
# Basic subscription users show higher churn compared to premium users
# Customer engagement plays an important role in retention
# Spending patterns influence customer loyalty and churn behavior
# Improving customer service can significantly reduce churn
# Identifying high-risk customers can help in better retention strategies
